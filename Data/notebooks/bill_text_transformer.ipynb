# %%
# !pip install transformers datasets evaluate accelerate
# Out:
# ...
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# ...
#    ---------------------------------------- 0.0/109.3 MB ? eta -:--:--
#    ----- ---------------------------------- 16.3/109.3 MB 78.8 MB/s eta 0:00:02
#    ------------ --------------------------- 34.3/109.3 MB 83.9 MB/s eta 0:00:01
#    ------------------ --------------------- 51.6/109.3 MB 86.5 MB/s eta 0:00:01
#    ------------------------- -------------- 68.9/109.3 MB 84.6 MB/s eta 0:00:01
#    ------------------------------- -------- 87.0/109.3 MB 85.5 MB/s eta 0:00:01
#    ------------------------------------- - 105.4/109.3 MB 86.2 MB/s eta 0:00:01
#    ---------------------------------------- 109.3/109.3 MB 81.1 MB/s  0:00:01
# ...
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 2.0/2.0 MB 57.2 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
# ...

# %%
import pandas as pd
import numpy as np

# %%
PATH = r"C:\Users\Connor McCranie\bills_text\bill_text_id.csv"
bills = pd.read_csv('../csv/cleaned_bills.csv')
text = pd.read_csv(PATH).dropna()
bills.iloc[1000]
# Out:
# Unnamed: 0                                     1000
# congress                                        119
# bill_type                                         S
# number                                         2722
# chamber                                           S
# date                            2025-09-04 00:00:00
# sponsor_party                                     R
# policy_area                   International Affairs
# passed_senate                                 False
# passed_house                                  False
# to_president                                  False
# law                                           False
# id                                       119.S.2722
# house_democrat_members                        219.0
# house_independent_members                       0.0
# house_republican_members                      224.0
# senate_democrat_members                        45.0
# senate_independent_members                      2.0
# ...

# %%
text[text.id == '118.HR.9014']
# Out:
#                id                                          full_text
# 1388  118.HR.9014  <!DOCTYPE html><html lang="en-US"><head><title...

# %%
df = pd.merge(bills, text, on='id')
two_terms = df[df.date >= '2017-01-20'] # inaguration day
two_terms['passed'] = two_terms.law.apply(lambda x: 'yes' if x else 'no')
# Out:
# C:\Users\Connor McCranie\AppData\Local\Temp\ipykernel_18544\2969723628.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   two_terms['passed'] = two_terms.law.apply(lambda x: 'yes' if x else 'no')

# %%
two_terms[two_terms.id == '118.HR.9014']
# Out:
#       Unnamed: 0  congress bill_type  number chamber                 date  \
# 1202       12966       118        HR    9014       H  2024-07-11 00:00:00
#
#      sponsor_party policy_area  passed_senate  passed_house  ...           id  \
# 1202             D         Law          False         False  ...  118.HR.9014
#
#       house_democrat_members house_independent_members  \
# 1202                   221.0                       0.0
#
#       house_republican_members  senate_democrat_members  \
# 1202                     230.0                     52.0
#
#       senate_independent_members  senate_republican_members  pres_party  \
# 1202                         4.0                       49.0    Democrat
#
#                                               full_text passed
# 1202  <!DOCTYPE html><html lang="en-US"><head><title...     no
#
# [1 rows x 22 columns]

# %%
two_terms.full_text[0][:6] =='<html>'
valid = two_terms.full_text.apply(lambda x: x[:6]=='<html>' )
df = two_terms[valid][['full_text', 'passed']]
two_terms[~valid]
# Out:
#        Unnamed: 0  congress bill_type  number chamber                 date  \
# 1197        12959       118     HJRES     185       H  2024-07-11 00:00:00
# 1199        12962       118     HJRES     183       H  2024-07-11 00:00:00
# 1200        12963       118     HJRES     186       H  2024-07-11 00:00:00
# 1201        12965       118        HR    9021       H  2024-07-11 00:00:00
# 1202        12966       118        HR    9014       H  2024-07-11 00:00:00
# ...           ...       ...       ...     ...     ...                  ...
# 12688       47240       115        HR     775       H  2017-01-31 00:00:00
# 12691       47258       115     HJRES      46       H  2017-01-30 00:00:00
# 12692       47259       115     HJRES      45       H  2017-01-30 00:00:00
# 12693       47267       115        HR     733       H  2017-01-30 00:00:00
# 12698       47375       115         S     181       S  2017-01-20 00:00:00
#
# ...

# %%
valid_text = text.full_text.apply(lambda x: x[:6]=='<html>' )

# %%
text[valid_text]
# Out:
#                     id                                          full_text
# 0          119.HRES.27  <html><body><pre>\n[Congressional Bills 119th ...
# 2          118.HR.9124  <html><body><pre>\n[118th Congress Public Law ...
# 3          118.HR.8667  <html><body><pre>\n[118th Congress Public Law ...
# 4           119.HRES.4  <html><body><pre>\n[Congressional Bills 119th ...
# 5           119.HRES.3  <html><body><pre>\n[Congressional Bills 119th ...
# ...                ...                                                ...
# 46953      104.HR.3650  <html><body><pre>\n[Congressional Bills 104th ...
# 46954  104.HCONRES.185  <html><body><pre>\n[Congressional Bills 104th ...
# 46955  104.HCONRES.186  <html><body><pre>\n[Congressional Bills 104th ...
# 46956      104.HR.3597  <html><body><pre>\n[Congressional Bills 104th ...
# 46957       104.S.1865  <html><body><pre>\n[Congressional Bills 104th ...
#
# [15550 rows x 2 columns]
